# %%
# Import the required library
import pickle

# Model Filename
model_file = "finalized_model_multiple_linear.sav"

# Open the model file
loaded_model = pickle.load(open(model_file, "rb"))

# Prediction
# Always provide all the inputs that we used train the model.
result = loaded_model.predict([[165349.20, 136897.80, 471784.10, 0, 0]])
result[0][0]
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(191934.86830489873)
