# %%
# Running the model without preprocessing the input
# Load the saved model back from the file
# Without preprocessing the inputs, we can't get the expected output.
import pickle
loaded_model = pickle.load(open("finalized_svmr.sav", "rb"))

unprocessed_input_to_predict = [[10000, 12000, 15000, 0, 0]]

result = loaded_model.predict(unprocessed_input_to_predict)
result
# Out:
# array([1.00461895e+13])

# %%
# Reversing the output by regeneration the standard scalar
import pandas as pd

# Load dataset
dataset = pd.read_csv("50_Startups.csv")
# Transform categorical data
dataset = pd.get_dummies(dataset, drop_first=True, dtype="int64")
# Split indenpendent and dependent variables
independent = dataset[["R&D Spend", "Administration", "Marketing Spend", "State_Florida", "State_New York"]]
dependent = dataset[["Profit"]]
# Split train and test dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# Regenerating the standard scalar
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# Preprocessing the input
preprocessed_input_to_predict = sc.transform([[10000, 12000, 15000, 0, 0]])
preprocessed_input_to_predict

# Load the saved model back from the file
import pickle
loaded_model = pickle.load(open("finalized_svmr.sav", "rb"))
result = loaded_model.predict(preprocessed_input_to_predict)
result
# Out:
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([108646.70978813])

# %%
# Reversing the output by reusing the saved standard scalar
import pickle

# Load the previously trained StandardScaler
with open("standard_scalar.pkl", "rb") as file:
    sc = pickle.load(file)
    print("Scaler loaded successfully!")

# Preprocessing the input
preprocessed_input_to_predict = sc.transform([[10000, 12000, 15000, 0, 0]])
preprocessed_input_to_predict

# Load the saved model back from the file
loaded_model = pickle.load(open("finalized_svmr.sav", "rb"))
result = loaded_model.predict(preprocessed_input_to_predict)
result

# array([1.00461895e+13])
# Out:
# Scaler loaded successfully!
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([108646.70978813])
